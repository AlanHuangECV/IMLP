# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.5900305420664328

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color = "b")
plt.plot(x, regr_poly.predict(X_poly), 'r')
plt.show()

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-1.59866051  2.11432572 -0.91762903  0.1883742  -0.01426412]
# interception:  1.0475977412243407

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([1.04759774, 0.97213346, 0.90676317, 0.85082103, 0.80366945,
#        0.76469857, 0.73332571, 0.7089948 , 0.69117578, 0.6793641 ,
#        0.6730801 , 0.67186849, 0.67529777, 0.68295966, 0.69446854,
#        0.7094609 , 0.72759479, 0.7485492 , 0.77202358, 0.79773718,
#        0.82542859, 0.8548551 , 0.88579218, 0.91803289, 0.95138734,
#        0.98568212, 1.02075972, 1.05647801, 1.09270964, 1.12934147,
#        1.16627405, 1.20342102, 1.24070857, 1.27807486, 1.31546947,
#        1.35285285, 1.3901957 , 1.42747849, 1.46469084, 1.50183096,
#        1.53890514, 1.5759271 , 1.61291751, 1.64990339, 1.68691754,
#        1.72399799, 1.76118745, 1.79853272, 1.83608415, 1.87389507,
#        1.91202121, 1.95052017, 1.98945085, 2.02887285, 2.06884597,
#        2.10942958, 2.15068213, 2.19266052, 2.23541957, 2.27901147,
#        2.32348519, 2.36888593, 2.41525456, 2.46262705, 2.51103391,
#        2.56049965, 2.61104218, 2.66267225, 2.71539293, 2.76919901,
#        2.82407644, 2.88000179, 2.93694164, 2.99485209, 3.05367814,
#        3.11335313, 3.17379822, 3.23492178, 3.29661885, 3.35877058,
#        3.42124367, 3.48388979, 3.54654501, 3.60902929, 3.67114587,
#        3.7326807 , 3.79340192, 3.85305927, 3.91138354, 3.96808598,
#        4.02285777, 4.07536945, 4.12527035, 4.17218802, 4.21572769,
#        4.25547168, 4.29097889, 4.32178415, 4.34739774, 4.36730479])

# %%
regr_poly.predict(X_poly)
# Out:
# array([1.04759774, 0.97213346, 0.90676317, 0.85082103, 0.80366945,
#        0.76469857, 0.73332571, 0.7089948 , 0.69117578, 0.6793641 ,
#        0.6730801 , 0.67186849, 0.67529777, 0.68295966, 0.69446854,
#        0.7094609 , 0.72759479, 0.7485492 , 0.77202358, 0.79773718,
#        0.82542859, 0.8548551 , 0.88579218, 0.91803289, 0.95138734,
#        0.98568212, 1.02075972, 1.05647801, 1.09270964, 1.12934147,
#        1.16627405, 1.20342102, 1.24070857, 1.27807486, 1.31546947,
#        1.35285285, 1.3901957 , 1.42747849, 1.46469084, 1.50183096,
#        1.53890514, 1.5759271 , 1.61291751, 1.64990339, 1.68691754,
#        1.72399799, 1.76118745, 1.79853272, 1.83608415, 1.87389507,
#        1.91202121, 1.95052017, 1.98945085, 2.02887285, 2.06884597,
#        2.10942958, 2.15068213, 2.19266052, 2.23541957, 2.27901147,
#        2.32348519, 2.36888593, 2.41525456, 2.46262705, 2.51103391,
#        2.56049965, 2.61104218, 2.66267225, 2.71539293, 2.76919901,
#        2.82407644, 2.88000179, 2.93694164, 2.99485209, 3.05367814,
#        3.11335313, 3.17379822, 3.23492178, 3.29661885, 3.35877058,
#        3.42124367, 3.48388979, 3.54654501, 3.60902929, 3.67114587,
#        3.7326807 , 3.79340192, 3.85305927, 3.91138354, 3.96808598,
#        4.02285777, 4.07536945, 4.12527035, 4.17218802, 4.21572769,
#        4.25547168, 4.29097889, 4.32178415, 4.34739774, 4.36730479])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.72626474 -1.74143599  1.41214567  0.33870019  3.42708055]
# interception:  1.7304742523857712

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()
plt.show()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.5900305420664328

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.5276786138160054

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.2419232902407611

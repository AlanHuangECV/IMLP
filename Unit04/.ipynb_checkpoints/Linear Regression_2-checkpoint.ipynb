# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
# Out:
# [4.08163265 1.73469388 1.83673469 0.         2.75510204 3.36734694
#  3.67346939 4.28571429 1.02040816 0.30612245 4.18367347 1.32653061
#  4.69387755 0.20408163 3.87755102 3.97959184 0.51020408 4.3877551
#  3.7755102  3.06122449 0.6122449  2.95918367 1.63265306 1.93877551
#  5.         4.48979592 2.14285714 3.26530612 3.46938776 0.71428571
#  2.24489796 1.12244898 2.04081633 0.91836735 4.89795918 2.85714286
#  3.16326531 1.53061224 2.65306122 3.57142857]

# %%
y
# Out:
# array([1.04077906, 1.12342889, 1.53984727, 1.31024106, 1.96199219,
#        1.39125819, 0.91459645, 0.59091825, 1.57770204, 1.88439592,
#        1.60182257, 1.4465853 , 2.16852854, 2.94837776, 2.95721189,
#        3.62332961, 2.13153852, 3.29047999, 1.90044384, 3.52944449,
#        4.62953892, 4.95636884, 3.67650109, 3.32281336, 3.9757667 ,
#        3.06035307, 4.73363758, 3.7526639 , 2.92726812, 5.30128699,
#        4.38259239, 3.82891815, 4.28154982, 4.98769251, 4.37099512,
#        4.38129857, 5.22531537, 4.3875521 , 6.63506219, 6.10018699,
#        6.20386574, 4.63269694, 6.76684191, 5.99485516, 6.42550618,
#        5.46389665, 7.46624265, 6.31122755, 6.09333229, 8.07098139])

# %%
plt.scatter(x_train, y_train)
plt.show()

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr = LinearRegression()
X_train = x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.24973162]
# interception:  0.7256913633991262

# %%
Y_train = regr.predict(X_train)

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.5699404876442852

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, Y_train, 'r')
plt.show()

# %% [markdown]
# #### test with test data

# %%
X_test = x_test.reshape(-1,1)
Y_test = regr.predict(X_test)

print(Y_test)
# Out:
# [2.25597498 2.51102225 1.2357859  1.74588044 6.46425493 0.853215
#  3.91378223 3.7862586  6.7193022  3.65873496]

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
W=regr.coef_
b=regr.intercept_
W*X_test+b
# Out:
# array([[2.25597498],
#        [2.51102225],
#        [1.2357859 ],
#        [1.74588044],
#        [6.46425493],
#        [0.853215  ],
#        [3.91378223],
#        [3.7862586 ],
#        [6.7193022 ],
#        [3.65873496]])

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
# Out:
# 0.28797467518828923

# %%
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
plt.show()

# %% [markdown]
# ## 基礎題 - 算出斜率w與截距b
#
# y = wx + b
#
# 記得計算前X須符合資料格式
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.datasets import get_data_home
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#將模型工具指派給一變數做使用
#注意轉換x得格式1D->2D
#將x,y資料導入LinearRegression演算法做訓練
#列印出訓練完成之函數的斜率與截距
#  一樣用LinearRegression涵式
regr_lin = LinearRegression() # 1.先assign
X = x.reshape(-1, 1) # 2.X_train要變成二維
# print(X.shape)
regr_lin.fit(X,y) #3. 然後將資料(X2D_train,y_train)丟給機器做學習

Predict_Y = regr_lin.predict(X) # 4. 將X2D_train丟去預測Y_train
plt.scatter(x,y) # 原本
plt.plot(x,Predict_Y , color='r') # 預測
plt.show()
MSE = np.sum((Predict_Y-y)**2) / len(y)
print(f"MSE : {MSE}")
print('Coefficients(斜率w): ', regr_lin.coef_) # 斜率
print('interception(截距b): ', regr_lin.intercept_) # 截距b,
# Out:
# MSE : 0.26267606969489105
# Coefficients(斜率w):  [1.61701852]
# interception(截距b):  0.27312968949421723

# %% [markdown]
# ## 進階題 - 切割資料集分別做訓練與預測(訓練資料80%、測試資料20%)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#匯入在sklearn.model_selection套件裡面的train_test_split模組
#切割數據集(訓練資料80%、測試資料20%，設定random_state=20)
#畫出訓練資料集的matplotlib圖形m
# X = x.reshape(-1, 1) # 2.X_train要變成二維
# random_state如果有設每次random(打亂數據集會固定,方便複測驗證)會是一樣的(類似種子號碼)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print("x_train:")
print(x_train)

print(f"x_train.shape: {x_train.shape}")
# print(f"X_test:")
# print(X_test.head())
print(f"x_test.shape: {x_test.shape}")
# print(f"Y_train:")
# print(Y_train.head())
print(f"y_train.shape: {y_train.shape}")
# print(f"Y_test:")
# print(Y_test.head())
print(f"y_test.shape: {y_test.shape}")

print("畫圖(x_train, y_train):")
plt.scatter(x_train, y_train)
plt.show()
# Out:
# x_train:
# [ 8.16326531  3.46938776  3.67346939  0.          5.51020408  6.73469388
#   7.34693878  8.57142857  2.04081633  0.6122449   8.36734694  2.65306122
#   9.3877551   0.40816327  7.75510204  7.95918367  1.02040816  8.7755102
#   7.55102041  6.12244898  1.2244898   5.91836735  3.26530612  3.87755102
#  10.          8.97959184  4.28571429  6.53061224  6.93877551  1.42857143
#   4.48979592  2.24489796  4.08163265  1.83673469  9.79591837  5.71428571
#   6.32653061  3.06122449  5.30612245  7.14285714]
# x_train.shape: (40,)
# x_test.shape: (10,)
# y_train.shape: (40,)
# y_test.shape: (10,)
# 畫圖(x_train, y_train):

# %% [markdown]
# ## 用訓練資料來 fit 函數
# 1. 只用訓練資料集的資料進行linear regression演算法<br>
# 2. 並計算出訓練階段的MSE
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_train.PNG)

# %%
#  一樣用LinearRegression涵式
regr_lin = LinearRegression() # 1.先assign
X2D_train = x_train.reshape(-1, 1) # 2.X_train要變成二維
# print(X.shape)
regr_lin.fit(X2D_train,y_train) #3. 然後將資料(X2D_train,y_train)丟給機器做學習

Predict_Y = regr_lin.predict(X) # 4. 將X2D_train丟去預測Y_train
plt.scatter(x,y) # 原本
plt.plot(x,Predict_Y , color='r') # 預測
plt.show()
MSE = np.sum((Predict_Y-y)**2) / len(y)
print(f"MSE : {MSE}")
print('Coefficients(斜率w): ', regr_lin.coef_) # 斜率
print('interception(截距b): ', regr_lin.intercept_) # 截距b,
# Out:
# MSE : 0.2654477691926312
# Coefficients(斜率w):  [1.60659227]
# interception(截距b):  0.36802581786862376

# %% [markdown]
# ## 將訓練出來的函數預測測試集的X值
# 1. 使用剛剛訓練出來的模型進行測試資料集的資料預測*注意reshape<br>
# 使用X = 2.44897959，預測出來數值應該為 4.3025375<br>
# 所有測試集資料
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
X_test = x_test.reshape(-1, 1) # 2.X_train要變成二維
X = 2.44897959
W=regr_lin.coef_
b=regr_lin.intercept_
Predict_Y_test = W*X_test+b
YY = W*X+b
print(YY)
plt.scatter(x,y) # 原本
plt.plot(x,Predict_Y , color='r') # 預測
plt.plot(x_test,Predict_Y_test , color='g') # 預測
plt.show()
# Out:
# [4.3025375]

# %%
Y_test_MSE = np.sum((Predict_Y_test.T-y_test)**2) / len(y_test)
print(f"Y_test_MSE : {Y_test_MSE}")
# Out:
# Y_test_MSE : 0.41344072565862955

# %% [markdown]
# 2. 並計算出測試階段的MSE

# %%
# ======最後===========================
title='f(x)=1.6x+0.37'+',mse:'+str(round(Y_test_MSE,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Predict_Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
plt.show()

# %% [markdown]
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_test.PNG)
